# %%
import matplotlib.pyplot as plt
import numpy as np

#to avoid coding plt.show()
# %matplotlib inline

# %%
x=np.arange(0,10)
y=np.arange(10,20)

# %%
# axis=plt.axes()
# axis.set_facecolor('black')

# %%
#plt.scatter(x,y,color="red")
#above code is also true
plt.scatter(x,y,c="r")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.savefig('demo.jpg')

# %%
y=x*x

# %%
plt.plot(x,y,'y--')

# %%
#plt.subplot(rows,cols,nth graph)
plt.subplot(1,2,1)
plt.plot(x,y,'r*')
plt.subplot(1,2,2)
plt.plot(x,y,'g*')

# %%
# Trignometric curves
a=np.arange(0,6*np.pi,0.1)
y1=np.cos(x)
y2=np.sin(x)

plt.subplot(2,1,1)
plt.plot(a,y1,'r--')
plt.subplot(2,1,2)
plt.plot(a,y1,'b--')

# %%
x=[5,6,7]
y=[1,2,3]
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.hist(x,bins=5)
# Out:
# (array([1., 0., 1., 0., 1.]),
#  array([5. , 5.4, 5.8, 6.2, 6.6, 7. ]),
#  <BarContainer object of 5 artists>)

# %%
size=[300,200,150]
labels=['python','C++','Java']
colors=['red','yellow','green']

plt.pie(size,explode=None,labels=labels,colors=colors,autopct='%.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x29f7bfb02b0>,
# ...
#  [Text(0.13259034041635367, 1.0919797624627827, 'python'),
#   Text(-0.8233617862141808, -0.7294349655741723, 'C++'),
#   Text(0.8233618886561177, -0.7294348499411245, 'Java')],
#  [Text(0.07232200386346563, 0.5956253249796997, '46.15%'),
#   Text(-0.44910642884409857, -0.3978736175859121, '30.77%'),
#   Text(0.4491064847215187, -0.3978735545133406, '23.08%')])
